# %%
import pandas as pd
import numpy as np

# %%
def countAnalysis(name, df):
    import matplotlib.pyplot as plt
    
    print(name, " applicationLabel count")
    print(df['experiment/applicationLabel'].value_counts(sort=False).sort_index())
    print()
    
    print(name, " faultLabel count")
    print(df['faultLabel'].value_counts(sort=False).sort_index())
    print()
    
    print(name, " faultPred count and")
    print(df['faultPred'].value_counts(sort=False).sort_index())
    print()
    
    df['experiment/applicationLabel'].value_counts(sort=False).sort_index().plot(kind='bar').set_title(name + " applicationLabel")
    plt.show()
    df['faultLabel'].value_counts(sort=False).sort_index().plot(kind='bar').set_title(name + " faultLabel")
    plt.show()
    df['faultPred'].value_counts(sort=False).sort_index().plot(kind='bar').set_title(name + " faultPred")
    plt.show()

# %%
def removeCPUMetrics(df):
    df = df.loc[:, ~df.columns.str.contains('cpu[0-9]')]
    return df

# %%
node1 = 'mpp3r02c05s07'
node2 = 'mpp3r02c05s08'
node3 = 'mpp3r02c05s09'
node4 = 'mpp3r02c05s10'

node1_df = pd.read_csv('/run/media/vincenzo/TOSHIBA EXT/CovellaScript/exp4/computeNodesCSV/' + node1 + ".csv", header=0, index_col=0, parse_dates=True)
node1_df = removeCPUMetrics(node1_df)
node2_df = pd.read_csv('/run/media/vincenzo/TOSHIBA EXT/CovellaScript/exp4/computeNodesCSV/' + node2 + ".csv", header=0, index_col=0, parse_dates=True)
node2_df = removeCPUMetrics(node2_df)
node3_df = pd.read_csv('/run/media/vincenzo/TOSHIBA EXT/CovellaScript/exp4/computeNodesCSV/' + node3 + ".csv", header=0, index_col=0, parse_dates=True)
node3_df = removeCPUMetrics(node3_df)
node4_df = pd.read_csv('/run/media/vincenzo/TOSHIBA EXT/CovellaScript/exp4/computeNodesCSV/' + node4 + ".csv", header=0, index_col=0, parse_dates=True)
node4_df = removeCPUMetrics(node4_df)

# %%
namelist = [node1, node2, node3, node4]
nodelist = [node1_df, node2_df, node3_df, node4_df]

for name, node in zip(namelist, nodelist):
    countAnalysis(name, node)
# Out:
# mpp3r02c05s07  applicationLabel count
# 0.0     32475
# 20.0    43982
# 21.0     5730
# 22.0    34439
# 23.0    36072
# 24.0    13177
# Name: experiment/applicationLabel, dtype: int64
#
# mpp3r02c05s07  faultLabel count
# 0.0    24525
# 1.0    18284
# 2.0    17840
# 3.0    22195
# 4.0    19011
# 5.0    22402
# 6.0    18813
# 7.0    22805
# Name: faultLabel, dtype: int64
#
# mpp3r02c05s07  faultPred count and
# 0.0    118027
# 1.0       556
# 2.0      8354
# 3.0        24
# 4.0        14
# 5.0     23900
# 6.0      5714
# 7.0      9286
# Name: faultPred, dtype: int64
# mpp3r02c05s08  applicationLabel count
# 0.0     32482
# 20.0    43980
# 21.0     5726
# 22.0    34439
# 23.0    36074
# 24.0    13174
# Name: experiment/applicationLabel, dtype: int64
#
# mpp3r02c05s08  faultLabel count
# 0.0    165875
# Name: faultLabel, dtype: int64
#
# mpp3r02c05s08  faultPred count and
# 0.0    165875
# Name: faultPred, dtype: int64
# mpp3r02c05s09  applicationLabel count
# 0.0     32481
# 20.0    43974
# 21.0     5731
# 22.0    34437
# 23.0    36073
# 24.0    13178
# Name: experiment/applicationLabel, dtype: int64
#
# mpp3r02c05s09  faultLabel count
# 0.0    165874
# Name: faultLabel, dtype: int64
#
# mpp3r02c05s09  faultPred count and
# 0.0    165874
# Name: faultPred, dtype: int64
# mpp3r02c05s10  applicationLabel count
# 0.0     32474
# 20.0    43981
# 21.0     5731
# 22.0    34439
# 23.0    36074
# 24.0    13175
# Name: experiment/applicationLabel, dtype: int64
#
# mpp3r02c05s10  faultLabel count
# 0.0    165874
# Name: faultLabel, dtype: int64
#
# mpp3r02c05s10  faultPred count and
# 0.0    165874
# Name: faultPred, dtype: int64
