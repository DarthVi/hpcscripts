# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/run/media/vincenzo/TOSHIBA EXT/CovellaScript/exp15/computeNodesCSV/featuresCSV/mpp3r03c04s03_11f_60s_1step_mode.csv", header=0)

# %%
import matplotlib.pyplot as plt

df['label'].value_counts(sort=False).sort_index().plot(kind='bar').set_title("Label bar plot")
plt.show()
